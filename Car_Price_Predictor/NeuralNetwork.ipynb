# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras as ks
from sklearn.model_selection import train_test_split
import numpy as np
import warnings
warnings.filterwarnings('ignore', module='pandas', category=UserWarning)

# %%
df = pd.read_csv("car_price.csv")
df
# Out:
#                                     car_name car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1               Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                         Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                          Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4           Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
# ...                                      ...                 ...         ...
# 5507                 BMW X1 sDrive 20d xLine          28.90 Lakh  45,000 kms
# 5508                   BMW M Series M4 Coupe          64.90 Lakh  29,000 kms
# 5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh  90,000 kms
# 5510                      BMW 7 Series 730Ld          29.90 Lakh  79,000 kms
# 5511               BMW 5 Series 520d M Sport          31.90 Lakh  42,000 kms
#
#      fuel_type transmission  ownership  manufacture   engine    Seats
# 0       Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1       Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2       Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3       Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4       Petrol       Manual  1st Owner         2016  1199 cc  5 Seats
# ...        ...          ...        ...          ...      ...      ...
# 5507    Diesel    Automatic  1st Owner         2018  2995 cc  7 Seats
# 5508    Petrol    Automatic  2nd Owner         2015  1968 cc  5 Seats
# 5509    Diesel    Automatic  2nd Owner         2013  2755 cc  5 Seats
# 5510    Diesel    Automatic  3rd Owner         2015  2967 cc  6 Seats
# 5511    Diesel    Automatic  2nd Owner         2017  1991 cc  5 Seats
#
# [5512 rows x 9 columns]

# %% [markdown]
# Checking null values

# %%
df.loc[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [car_name, car_prices_in_rupee, kms_driven, fuel_type, transmission, ownership, manufacture, engine, Seats]
# Index: []

# %% [markdown]
# Duplicates

# %%
df = df.drop_duplicates()

# %%
print(df["car_prices_in_rupee"].str.extract(r"([a-zA-Z]+)")[0].unique())

print(df["kms_driven"].str.extract(r"([a-zA-Z]+)")[0].unique())

print(df["fuel_type"].unique())

print(df["engine"].str.extract(r"([a-zA-Z]+)")[0].unique())
print(df["transmission"].unique())

print(df["ownership"].unique())

print(df["Seats"].str.extract(r"([a-zA-Z]+)")[0].unique())
# Out:
# ['Lakh' 'Crore' nan]
# ['kms']
# ['Diesel' 'Petrol' 'Cng' 'Electric' 'Lpg']
# ['cc']
# ['Manual' 'Automatic']
# ['1st Owner' '2nd Owner' '3rd Owner' '4th Owner' '5th Owner' '0th Owner']
# ['Seats']

# %%
df.ownership.value_counts()
# Out:
# ownership
# 1st Owner    3678
# 2nd Owner    1298
# 3rd Owner     358
# 4th Owner      84
# 5th Owner      12
# 0th Owner       6
# Name: count, dtype: int64

# %%
df = df.drop(df[df["ownership"] == "0th Owner"].index)

# %% [markdown]
# Rupee to Euro

# %%
def rupee_to_euro(price): # 1 rupee = 0.01123 euro
    price = price.replace(",", ".")
    if("Lakh" in price):
        return float(price.replace(" Lakh", ""))  * 100000 * 0.01123
    elif("Crore" in price):
        return float(price.replace(" Crore", "").replace(",", ".")) * 10000000 * 0.01123
    else:
        return float(price)


df["car_prices_in_rupee"] = df["car_prices_in_rupee"].apply(rupee_to_euro)

# %%
df = df.rename(columns={"car_prices_in_rupee": "price_euro"})

# %% [markdown]
# kms object to float

# %%
def convert_kms(kms):
    kms = kms.replace(" kms", "")
    return float(kms.replace(",", ".", 1).replace(",", ""))

df["kms_driven"] = df["kms_driven"].apply(convert_kms)

# %%
df["ownership"] = df["ownership"].str.replace(r"(st|nd|rd|th) Owner", "", regex=True).astype(int)
df["engine"] = df["engine"].str.replace(" cc", "").astype(int)
df["Seats"] = df["Seats"].str.replace(" Seats", "").astype(int)

# %% [markdown]
# Encoding

# %%
df["transmission"] = df["transmission"].apply(lambda x: int(x=="Automatic"))
df = df.rename(columns={"transmission": "is_automatic"})
df
# Out:
#                                     car_name  price_euro  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV    11263.69      86.226
# 1               Renault Duster RXZ Turbo CVT    14408.09      13.248
# 2                         Toyota Camry 2.5 G    18417.20      60.343
# 3                          Honda Jazz VX CVT     8725.71      26.696
# 4           Volkswagen Polo 1.2 MPI Highline     5783.45      69.414
# ...                                      ...         ...         ...
# 5507                 BMW X1 sDrive 20d xLine    32454.70      45.000
# 5508                   BMW M Series M4 Coupe    72882.70      29.000
# 5509              Jaguar XF 2.2 Litre Luxury    15441.25      90.000
# 5510                      BMW 7 Series 730Ld    33577.70      79.000
# 5511               BMW 5 Series 520d M Sport    35823.70      42.000
#
#      fuel_type  is_automatic  ownership  manufacture  engine  Seats
# 0       Diesel             0          1         2017    1956      5
# 1       Petrol             1          1         2021    1330      5
# 2       Petrol             1          1         2016    2494      5
# 3       Petrol             1          1         2018    1199      5
# 4       Petrol             0          1         2016    1199      5
# ...        ...           ...        ...          ...     ...    ...
# 5507    Diesel             1          1         2018    2995      7
# 5508    Petrol             1          2         2015    1968      5
# 5509    Diesel             1          2         2013    2755      5
# 5510    Diesel             1          3         2015    2967      6
# 5511    Diesel             1          2         2017    1991      5
#
# [5430 rows x 9 columns]
